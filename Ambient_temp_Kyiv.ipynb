# %%
#Scrap the link with all data
import requests
from bs4 import BeautifulSoup

webpage_response = requests.get('https://www.climatestotravel.com/climate/ukraine/kiev')

soup = BeautifulSoup(webpage_response.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head><title>
# 	Kiev climate: weather by month, temperature, precipitation, when to go
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <style>
# body{background:#003566;background-attachment:fixed;font-size:1em;font-family:Georgia,"Times New Roman",Times,serif;margin:0;padding:0;color:#191970;font-display:swap}
# .corpo{display:flex;align-items:stretch;justify-content:space-around;width:70%;margin-left:auto;margin-right:auto;background-color:#E8F3FF}
# .corpo a:visited{color:purple}
# .corpo a:hover{color:#444}
# .corpo a:link{color:#00F}
# .skip_main{width:70%;background-color:#FFF;color:#FFF;margin-left:auto;margin-right:auto}
# .skip_main a:link{color:#FFF}
# .skip_main a:focus{background-color:#990000;color:#FFF!important}
# .skip_main a:visited{color:#FFF}
# .main{background-color:#FFF;font-size:1em;margin-left:auto;margin-right:auto}
# ...

# %%
#Scrap a table with the climate data
soup.find_all(attrs={'class':'div-tabella'})
# Out:
# [<div class="div-tabella"><table class="cities"><caption>Kiev - Average temperatures (1991-2020) </caption><colgroup><col/><col class="celsius" span="3"/><col class="fahrenheit" span="3"/></colgroup><tr class="title-table-new"><th scope="col">Month</th><th scope="col" title="Average low temperatures (degrees Celsius)">Min (°C)</th><th scope="col" title="Average high temperatures (degrees Celsius)">Max (°C)</th><th scope="col" title="Average daily temperature (degrees Celsius)">Mean (°C)</th><th scope="col" title="Average low temperatures (degrees Fahrenheit)">Min (°F)</th><th scope="col" title="Average high temperatures (degrees Fahrenheit)">Max (°F)</th><th scope="col" title="Average daily temperature (degrees Fahrenheit)">Mean (°F)</th></tr><tr class="min-table"><th scope="row" title="January">January</th><td>-5</td><td>-1</td><td>-3.1</td><td>22</td><td>30</td><td>26.4</td></tr><tr class="min-table"><th scope="row" title="February">February</th><td>-5</td><td>1</td><td>-2.2</td><t
# ...
