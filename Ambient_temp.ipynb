# %%
#Importing the required libraries
import pandas as pd

#Parsing HTML elements into a lis of data frames
df = pd.read_html("https://en.wikipedia.org/wiki/List_of_cities_by_average_temperature")

#Concatenating all datafrmaes into a single one
full_df = pd.concat([df[0], df[1], df[2], df[3], df[4], df[5]])
#Calling a function
full_df
# Out:
#       Country         City         Jan         Feb         Mar         Apr  \
# 0     Algeria      Algiers  11.2(52.2)  11.9(53.4)  12.8(55.0)  14.7(58.5)
# 1     Algeria  Tamanrasset  12.8(55.0)  15.0(59.0)  18.1(64.6)  22.2(72.0)
# 2     Algeria      Reggane  16.0(60.8)  18.2(64.8)  23.1(73.6)  27.9(82.2)
# 3      Angola       Luanda  26.7(80.1)  28.5(83.3)  28.6(83.5)  28.2(82.8)
# 4       Benin      Cotonou  27.3(81.1)  28.5(83.3)  28.9(84.0)  28.6(83.5)
# ..        ...          ...         ...         ...         ...         ...
# 51       Peru         Lima  22.1(71.8)  22.7(72.9)  22.2(72.0)  20.6(69.1)
# 52       Peru        Piura  26.8(80.2)  27.8(82.0)  27.8(82.0)  26.6(79.9)
# 53   Suriname   Paramaribo  26.0(78.8)  26.0(78.8)  26.2(79.2)  26.7(80.1)
# 54    Uruguay   Montevideo  23.0(73.4)  22.5(72.5)  20.6(69.1)  17.2(63.0)
# 55  Venezuela      Caracas  20.2(68.4)  20.8(69.4)  21.7(71.1)  22.7(72.9)
#
# ...
